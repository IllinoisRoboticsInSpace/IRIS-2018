# %%
import dummy_height_data_generator
import matplotlib.pyplot as plt
reload(dummy_height_data_generator)

def show(array_obj):
    plt.imshow(array_obj)
    plt.show()

a = dummy_height_data_generator.coord_system(100, 100)
a.scramble(3)
#print a.display()
show(a.display())
